# %%
import numpy as np
import os
from tqdm import tqdm

# %%
import nltk

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

nltk.download('wordnet')
from nltk.corpus import wordnet as wn

from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# [nltk_data] Downloading package punkt to /home/dyco/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/dyco/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /home/dyco/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# We don't want stopwords as they would probably just be noise:

# %%
nltk.download('stopwords')
en_stop = set(nltk.corpus.stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /home/dyco/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import gensim
from gensim import corpora

# %%
DATA_PATH = 'data'

# %% [markdown]
# Load summaries:

# %%
summaries = []
with open(os.path.join(DATA_PATH, 'plot_summaries.txt')) as ps:
    ps_text = ps.readlines()
    for line in ps_text[0:1000]:
        summaries.append(line.split('\t'))

# %% [markdown]
# Create dictionaries to extract nouns, verbs and descriptions (adverbs and adjectives):

# %%
is_noun = lambda pos: pos.startswith('NN')
nouns = {}

is_verb = lambda pos: pos.startswith('VB')
verbs = {}

is_desc = lambda pos: pos.startswith('RB') or pos.startswith('JJ')
descriptions = {}

# %% [markdown]
# Function to select only certain types of words (verbs, nouns or descriptions) from a list of tokens:

# %%
def get_pos_words(tokenized_text, pos_selection_function):
    return [word.lower()
            for (word, pos) in nltk.pos_tag(tokenized_text)
            if pos_selection_function(pos) and len(word) > 3]

# %% [markdown]
# Extract lemmas from words:

# %%
def get_lemmas(words):
    lemmas = []
    for word in words:
        lemma = wn.morphy(word)
        if lemma is None and word not in en_stop:
            lemmas.append(word)
        elif lemma is not None and lemma not in en_stop:
            lemmas.append(lemma)
    return lemmas

# %% [markdown]
# Call previously defined functions to prepate lists of verbs, nouns and descriptions:

# %%
def prepare_text(summary, nouns, verbs, descs):
    tokenized = nltk.word_tokenize(summary[1])
    
    nouns[summary[0]] =  get_pos_words(tokenized, is_noun)
    nouns[summary[0]] = get_lemmas(nouns[summary[0]])

    verbs[summary[0]] =  get_pos_words(tokenized, is_verb)
    verbs[summary[0]] = get_lemmas(verbs[summary[0]])

    descs[summary[0]] =  get_pos_words(tokenized, is_desc)
    descs[summary[0]] = get_lemmas(descs[summary[0]])

# %% [markdown]
# Process the data:

# %%
for summary in tqdm(summaries):
    prepare_text(summary, nouns, verbs, descriptions)
# Out:
# 100%|██████████| 1000/1000 [00:24<00:00, 40.67it/s]

# %%
def extract_tf_idf_features(dict_of_docs):
    raw_texts = [" ".join(words) for words in list(dict_of_docs.values())]
    tfidf_vectorizer = TfidfVectorizer()
    tfidf_matrix = tfidf_vectorizer.fit_transform(raw_texts)
    feature_names = tfidf_vectorizer.get_feature_names_out()
    mean_tfidf_scores = tfidf_matrix.mean(axis=0).tolist()[0]

    # Zip feature names with mean TF-IDF scores
    term_tfidf_pairs = zip(feature_names, mean_tfidf_scores)

    # Sort terms by mean TF-IDF score in descending order
    sorted_terms = sorted(term_tfidf_pairs, key=lambda x: x[1], reverse=True)

    # Set a threshold (e.g., keep top 80% of terms)
    threshold = 0.2
    selected_terms = [term for term, tfidf_score in sorted_terms if tfidf_score >= threshold]
    print(selected_terms)

    return selected_terms


for x in extract_tf_idf(nouns):
    print(x)
# Out:
# ['shlykov taxi driver lyosha saxophonist love-hate relationship prejudice', 'nation panem capitol district punishment rebellion district girl age lottery hunger game tribute death arena survivor fame wealth reap primrose everdeen district sister katniss volunteer place peeta mellark baker katniss bread district tribute katniss peeta capitol mentor victor haymitch abernathy career tribute academy interview caesar flickerman peeta love katniss ploy audience support sponsor gift food medicine tool peeta game begin half tribute minutes katniss haymitch advice melee supply weapon front structure cornucopia peeta alliance career katniss corner tree tree attention tracker jacker branch katniss besieger scatter glimmer insect jacker venom katniss peeta katniss couple days recover alliance supply pile katniss stockpile mine furious cato katniss scene name marvel tribute district spear katniss spear stomach katniss arrow song afterward gather flower body riot district president snow summons seneca crane gamemaker displeasure game katniss peeta public lover haymitch crane rule change riot district pair katniss peeta sword wound deeply love gain sponsor gift soup announcer feast thing survivor peeta medicine katniss feast clove clove gloat thresh district tribute kill clove torment katniss katniss time medicine peeta mobile foxface girl district die nightlock berry peeta crane time arena night pack creature things thresh force katniss peeta roof cornucopia cato battle katniss cato arrow peeta creature katniss cato death peeta katniss rule change winner peeta katniss half nightlock victor hunger game haymitch katniss enemy display defiance peeta district crane room bowl nightlock berry president snow situation', 'poovalli induchoodan years life classmate induchoodan justice maranchery karunakara menon case manapally madhavan nambiar crony dysp sankaranarayanan revenge idealist judge menon jail sentence manapally corruption case induchoodan rank indian civil service post manapally sudheeran saikumar list service trainee flashback ramakrishnan moopil nair classmate years pass manapally madhavan nambiar state minister induchoodan rage injustice life prison induchoodan manapally pavithran ritual nambiar bharathapuzha confrontation induchoodan manapally henchman induchoodan love anuradha aishwarya daughter mooppil nair justice menon wife return kerala induchoodan appearance girl indulekha kanaka daughter justice menon menon claim circumstances instigation help manapally pavithran claim induchoodan thrash protester truth chandrabhanu uncle task protection capacity elder brother induchoodan indulekha friend jayakrishnan induchoodan confrontation father prod mistake parentage indulekha menon daughter induchoodan poovally indulekha menon pavithran indulekha force raman nair menon court court nandagopal maarar friend induchoodan court lawyer menon manage murder plot intention party menon innocent crime court pavithran retribution crime indulekha induchoodan father remorse action innocence induchoodan menon heart stroke menon manapally pavithran induchoodan ritual father induchoodan avenge death sister father pavithran life induchoodan anuradha life partner', 'lemon drop york city swindler horse florida racetrack hustle beautiful woman money woman belong gangster moose moran money choice finish moran christmas year york money girlfriend brainy baxter talk commitment arise escape crime oxford charley dealings charley trouble care charley establishment hope cornerside santa claus kettle fashion santa suit donation passing policeman activity court charity license days jail court scheme stay brainy santa operation time backing charity city license inspiration nellie thursday resident entry retirement home husband past safecracker york swindler brainy apparent goodwill casino nellie thursday home doll group woman amenities project city license compatriot dress santa claus position manhattan others money moran scheme success days brainy dancer look home fu ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 22
#      17     print(selected_terms)
#      19     return selected_terms
# ---> 22 for x in extract_tf_idf(nouns):
#      23     print(x)
#
# TypeError: 'NoneType' object is not iterable

# %% [markdown]
# How's it going?

# %%
i=3
print(len(nouns[summaries[i][0]]))
print(verbs[summaries[i][0]])
print(descriptions[summaries[i][0]])
# Out:
# 222
# ['come', 'intend', 'convince', 'switch', 'employ', 'doe', 'demand', 'provide', 'make', 'decide', 'return', 'come', 'try', 'make', 'visit', 'past', 'falls', 'doe', 'leaf', 'give', 'notice', 'thinking', 'begin', 'collecting', 'fail', 'recognize', 'remember', 'land', 'convict', 'collecting', 'sentence', 'learn', 'go', 'arrive', 'bail', 'set', 'restart', 'need', 'represent', 'receive', 'remember', 'deny', 'organize', 'charm', 'convert', 'abandon', 'makeshift', 'complete', 'receive', 'collect', 'plan', 'keep', 'netting', 'decide', 'leave', 'inform', 'seeing', 'decide', 'muscle', 'reasoning', 'kidnap', 'move', 'learn', 'return', 'find', 'desert', 'go', 'clue', 'reveal', 'move', 'confront', 'manage', 'slip', 'track', 'voice', 'stewing', 'surprise', 'meet', 'escape', 'decide', 'recover', 'sneak', 'find', 'move', 'using', 'heighten', 'enter', 'make', 'avoid', 'sent', 'ensue', 'allow', 'escape', 'return', 'meet', 'appear', 'arrive', 'demand', 'leave', 'turn', 'hitting', 'revealing', 'occupy', 'hold', 'initiate', 'arrest', 'sentence', 'warn', 'keeping', 'assure', 'going', 'become', 'begin', 'reunite']
# ['illegally', 'tout', 'several', 'successful', 'gullible', 'prefabricate', 'unfortunately', 'notorious', 'dead', 'last', 'furious', 'first', 'on-again', 'off-again', 'however', 'long-term', 'quickly', 'next', 'local', 'serious', 'particularly', 'anyway', 'quickly', 'previous', 'underhanded', 'well', 'however', 'wrong', 'short', 'legitimate', 'kindly', 'neighborhood', 'jail', 'criminal', 'small-time', 'surprise', 'small', 'elderly', 'able', 'all-important', 'free', 'unaware', 'huge', 'overjoy', 'none', 'cheerfully', 'potential', 'wherever', 'late', 'oversized', 'true', 'angry', 'however', 'outside', 'elderly', 'secure', 'brief', 'narrowly', 'original', 'little', 'however', 'mainly', 'escape', 'still-loyal', 'earlier', 'necessary', 'main', 'free', 'joyously']

# %%
dictionary = corpora.Dictionary(list(verbs.values()))
corpus = [dictionary.doc2bow(text) for text in list(verbs.values())]

# %%
NUM_TOPICS = 20
ldamodel = gensim.models.LdaMulticore(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=15)
topics = ldamodel.print_topics(num_words=10)
for topic in topics:
    print(topic)
# Out:
# (0, '0.017*"come" + 0.015*"begin" + 0.014*"become" + 0.012*"make" + 0.011*"learn" + 0.010*"realize" + 0.009*"know" + 0.009*"help" + 0.008*"try" + 0.007*"turn"')
# (1, '0.026*"find" + 0.021*"take" + 0.018*"tell" + 0.018*"go" + 0.018*"try" + 0.014*"make" + 0.012*"want" + 0.012*"doe" + 0.011*"ask" + 0.009*"return"')
# (2, '0.024*"take" + 0.023*"come" + 0.017*"tell" + 0.014*"want" + 0.011*"become" + 0.011*"marry" + 0.010*"give" + 0.010*"show" + 0.010*"ask" + 0.009*"make"')
# (3, '0.027*"marry" + 0.021*"come" + 0.019*"find" + 0.017*"go" + 0.016*"falls" + 0.015*"meet" + 0.012*"take" + 0.011*"want" + 0.009*"offer" + 0.008*"get"')
# (4, '0.013*"come" + 0.013*"play" + 0.011*"take" + 0.011*"turn" + 0.010*"attempt" + 0.010*"give" + 0.010*"lightning" + 0.009*"begin" + 0.008*"cause" + 0.008*"doe"')
# (5, '0.010*"take" + 0.009*"kill" + 0.008*"decide" + 0.007*"include" + 0.007*"left" + 0.007*"fail" + 0.007*"launch" + 0.007*"find" + 0.007*"sending" + 0.007*"attack"')
# (6, '0.026*"kill" + 0.020*"find" + 0.017*"take" + 0.012*"begin" + 0.011*"become" + 0.010*"live" + 0.010*"go" + 0.010*"manage" + 0.008*"attack" + 0.008*"discover"')
# (7, '0.021*"find" + 0.021*"kill" + 0.020*"take" + 0.015*"tell" + 0.011*"come" + 0.011*"make" + 0.010*"go" + 0.010*"doe" + 0.009*"call" + 0.009*"become"')
# (8, '0.017*"make" + 0.015*"give" + 0.013*"help" + 0.011*"agree" + 0.010*"lose" + 0.010*"left" + 0.009*"take" + 0.008*"learn" + 0.008*"attack" + 0.007*"become"')
# (9, '0.017*"take" + 0.013*"use" + 0.012*"make" + 0.008*"go" + 0.008*"bring" + 0.008*"feature" + 0.007*"infect" + 0.007*"come" + 0.007*"start" + 0.007*"become"')
# (10, '0.019*"take" + 0.017*"continue" + 0.011*"play" + 0.011*"cover" + 0.011*"flying" + 0.010*"deliver" + 0.010*"come" + 0.009*"begin" + 0.009*"roll" + 0.009*"playing"')
# (11, '0.013*"make" + 0.011*"ask" + 0.010*"come" + 0.010*"kill" + 0.009*"appear" + 0.009*"get" + 0.009*"portray" + 0.008*"move" + 0.008*"say" + 0.008*"follow"')
# (12, '0.026*"become" + 0.011*"find" + 0.011*"begin" + 0.010*"take" + 0.009*"investigate" + 0.009*"lead" + 0.008*"kill" + 0.008*"die" + 0.008*"show" + 0.008*"steal"')
# (13, '0.015*"give" + 0.015*"make" + 0.013*"kill" + 0.011*"go" + 0.011*"take" + 0.010*"arrive" + 0.009*"catch" + 0.009*"begin" + 0.009*"find" + 0.009*"become"')
# (14, '0.034*"find" + 0.031*"take" + 0.013*"make" + 0.012*"try" + 0.011*"return" + 0.011*"tell" + 0.009*"become" + 0.009*"give" + 0.009*"come" + 0.008*"arrive"')
# (15, '0.015*"become" + 0.013*"take" + 0.013*"find" + 0.012*"grow" + 0.012*"start" + 0.011*"threaten" + 0.010*"develop" + 0.009*"perform" + 0.009*"dancing" + 0.008*"throw"')
# (16, '0.028*"tell" + 0.023*"kill" + 0.020*"find" + 0.016*"take" + 0.013*"get" + 0.013*"go" + 0.012*"make" + 0.012*"want" + 0.010*"meet" + 0.010*"give"')
# (17, '0.020*"kill" + 0.018*"find" + 0.015*"begin" + 0.014*"become" + 0.013*"take" + 0.011*"turn" + 0.009*"return" + 0.009*"decide" + 0.008*"use" + 0.008*"tell"')
# (18, '0.026*"cite" + 0.015*"allow" + 0.013*"want" + 0.012*"take" + 0.011*"begin" + 0.010*"follow" + 0.010*"pay" + 0.009*"start" + 0.009*"claim" + 0.008*"find"')
# (19, '0.035*"kill" + 0.022*"find" + 0.019*"take" + 0.013*"tell" + 0.013*"try" + 0.012*"come" + 0.012*"start" + 0.012*"taking" + 0.012*"doe" + 0.011*"make"')

# %%
print(verbs[summaries[i][0]])
new_doc_bow = dictionary.doc2bow(verbs[summaries[i][0]])
print(ldamodel.get_document_topics(new_doc_bow))
# Out:
# ['come', 'intend', 'convince', 'switch', 'employ', 'doe', 'demand', 'provide', 'make', 'decide', 'return', 'come', 'try', 'make', 'visit', 'past', 'falls', 'doe', 'leaf', 'give', 'notice', 'thinking', 'begin', 'collecting', 'fail', 'recognize', 'remember', 'land', 'convict', 'collecting', 'sentence', 'learn', 'go', 'arrive', 'bail', 'set', 'restart', 'need', 'represent', 'receive', 'remember', 'deny', 'organize', 'charm', 'convert', 'abandon', 'makeshift', 'complete', 'receive', 'collect', 'plan', 'keep', 'netting', 'decide', 'leave', 'inform', 'seeing', 'decide', 'muscle', 'reasoning', 'kidnap', 'move', 'learn', 'return', 'find', 'desert', 'go', 'clue', 'reveal', 'move', 'confront', 'manage', 'slip', 'track', 'voice', 'stewing', 'surprise', 'meet', 'escape', 'decide', 'recover', 'sneak', 'find', 'move', 'using', 'heighten', 'enter', 'make', 'avoid', 'sent', 'ensue', 'allow', 'escape', 'return', 'meet', 'appear', 'arrive', 'demand', 'leave', 'turn', 'hitting', 'revealing', 'occupy', 'hold', 'initiate', 'arrest', 'sentence', 'warn', 'keeping', 'assure', 'going', 'become', 'begin', 'reunite']
# [(12, 0.99173784)]

# %% [markdown]
# # Some experiments

# %%
from gensim.scripts.glove2word2vec import glove2word2vec
glove_model_path = 'models/glove.6B.50d.txt'
word2vec_output_path = 'models/glove.6B.50d.model'

# Convert GloVe to Word2Vec format
glove2word2vec(glove_model_path, word2vec_output_path)
# Out:
# /tmp/ipykernel_107053/121057109.py:6: DeprecationWarning: Call to deprecated `glove2word2vec` (KeyedVectors.load_word2vec_format(.., binary=False, no_header=True) loads GLoVE text vectors.).
#   glove2word2vec(glove_model_path, word2vec_output_path)
# (400000, 50)

# %%
from gensim.models import KeyedVectors
from sklearn.cluster import KMeans
import numpy as np

# Assume 'word_list' is your list of words
word_list = ['shoot', 'stab', 'slice', 'run', 'jump', 'swim', 'kill', 'play']

# Load pre-trained Word2Vec model (example, you may use a more extensive model)
model = KeyedVectors.load_word2vec_format('models/glove.6B.50d.model', binary=False)

# Get word vectors
word_vectors = [model[word] for word in word_list]

# Apply k-means clustering
num_clusters = 2  # Adjust based on your needs
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(word_vectors)

# Get cluster assignments for each word
cluster_assignments = kmeans.labels_

# Print clusters
for word, cluster in zip(word_list, cluster_assignments):
    print(f"{word}: Cluster {cluster}")
# Out:
# shoot: Cluster 1
# stab: Cluster 1
# slice: Cluster 1
# run: Cluster 0
# jump: Cluster 0
# swim: Cluster 0
# kill: Cluster 1
# play: Cluster 0
# /home/dyco/EPFL/SEMESTAR_1/ADA/PROJECT/ADA_Movie_Analysis/.venv/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
